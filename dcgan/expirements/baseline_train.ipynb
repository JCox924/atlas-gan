# %%
import sys
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

from models.dcgan_baseline import build_generator, build_discriminator

# Test the import by printing a summary of one model (optional)
# latent_dim = 100
# img_shape = (28, 28, 1)
# generator = build_generator(latent_dim)
# generator.summary()

# %%
print(os.getcwd())
data_path = os.path.abspath(os.path.join('..', 'data', 'mnist_preprocessed.npz'))
data = np.load(data_path)
x_train = data['x_train']

latent_dim = 100
img_shape = x_train.shape[1:]
epochs = 50
batch_size = 128
num_batches = x_train.shape[0] // batch_size

generator = build_generator(latent_dim)
discriminator = build_discriminator(img_shape)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

discriminator.trainable = False
noise_input = tf.keras.Input(shape=(latent_dim,))
generated_image = generator(noise_input)
validity = discriminator(generated_image)
combined = tf.keras.Model(noise_input, validity)
combined.compile(loss='binary_crossentropy', optimizer=optimizer)

def display_generated_images(generator, epoch, examples=16, dim=(4, 4), figsize=(4, 4)):
    noise = np.random.normal(0, 1, (examples, latent_dim))
    generated_images = generator.predict(noise)
    generated_images = (generated_images + 1) / 2.0

    fig, axs = plt.subplots(dim[0], dim[1], figsize=figsize, sharex=True, sharey=True)
    cnt = 0
    for i in range(dim[0]):
        for j in range(dim[1]):
            axs[i, j].imshow(generated_images[cnt, :, :, 0], cmap='gray')
            axs[i, j].axis('off')
            cnt += 1
    plt.suptitle(f'Epoch {epoch}')
    plt.tight_layout()
    plt.show()

for epoch in range(1, epochs + 1):
    for batch in range(num_batches):
        # ---------------------
        #  Train Discriminator
        # ---------------------
        idx = np.random.randint(0, x_train.shape[0], batch_size)
        real_imgs = x_train[idx]

        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        fake_imgs = generator.predict(noise)

        valid = np.ones((batch_size, 1))
        fake = np.zeros((batch_size, 1))

        d_loss_real = discriminator.train_on_batch(real_imgs, valid)
        d_loss_fake = discriminator.train_on_batch(fake_imgs, fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # ---------------------
        #  Train Generator
        # ---------------------
        # Train the generator via the combined model: try to trick the discriminator into believing that the generated images are real.
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        g_loss = combined.train_on_batch(noise, valid)

    print(f"Epoch {epoch}/{epochs} [D loss: {d_loss[0]:.4f}, acc: {d_loss[1]*100:.2f}%] [G loss: {g_loss:.4f}]")
    
    if epoch == 1 or epoch % 5 == 0:
        display_generated_images(generator, epoch)
# Out:
# C:\Users\Joshua\PycharmProjects\GANs\atlas-gan\dcgan\expirements
# ...
# 4/4 [==============================] - 0s 964us/step
# Epoch 1/50 [D loss: 0.7874, acc: 47.27%] [G loss: 1.2110]
# ...
# 4/4 [==============================] - 0s 1ms/step
# ...
# ...
# 4/4 [==============================] - 0s 2ms/step
# Epoch 50/50 [D loss: 0.6286, acc: 63.67%] [G loss: 0.9525]
# 1/1 [==============================] - 0s 12ms/step
